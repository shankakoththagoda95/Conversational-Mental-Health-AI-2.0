# %% [markdown]
# # 🧠 Questionnaire & Conversation Rating Pipeline
#
# This notebook extracts and rates responses for:
# - **PHQ-9** (depression)
# - **GAD-7** (anxiety)
# - **ASRM** (activation/mania)
# - **Casual conversations** (free talk between persona and friend)
#
# Each section:
# 1. Parses the JSONs from `Conversations/`
# 2. Extracts choice-based scores for structured questionnaires
# 3. Uses an LLM to infer scores from **casual dialogues**
# 4. Saves results in `Analysis/` as CSV files for further correlation studies

# %%
import os, json, csv, re
from pathlib import Path
from dotenv import load_dotenv
from openai import OpenAI

# Load environment (for OPENAI_API_KEY)
load_dotenv()
client = OpenAI()

# Utility
def ensure_dir(path):
    os.makedirs(os.path.dirname(path), exist_ok=True)

# %% [markdown]
# ## 📘 PHQ-9 Questionnaire Ratings
# Extracts numeric scores from `Conversations/PHQ9/Question based Conversation/*.json`
# Each answer includes `Choice:` lines like “Not at all”, “Several days”, etc.

# %%
# =================== PHQ-9 RATING SCRIPT ===================

INPUT_DIR = "Conversations/PHQ9/Question based Conversation"
OUTPUT_CSV = "Analysis/PHQ9/Questionnaire_summary.csv"
ensure_dir(OUTPUT_CSV)

CHOICE_MAP = {
    "not at all": 0,
    "several days": 1,
    "more than half the days": 2,
    "nearly every day": 3,
}

def extract_choice(answer: str):
    if not answer:
        return None
    text = answer.lower()
    m = re.search(r"choice\s*:\s*(.+)", text)
    choice = m.group(1).strip() if m else text
    for label, val in CHOICE_MAP.items():
        if label in choice:
            return val
    return None

def get_character_name(data, filename):
    if data.get("character"):
        return data["character"]
    items = data.get("Common Questions", [])
    if items:
        keys = list(items[0].keys())
        if "Consultant" in keys:
            keys.remove("Consultant")
        if keys:
            return keys[0]
    return os.path.splitext(filename)[0]

rows = []
for idx, fname in enumerate(sorted(os.listdir(INPUT_DIR)), start=1):
    if not fname.endswith(".json"): continue
    path = os.path.join(INPUT_DIR, fname)
    data = json.load(open(path, "r", encoding="utf-8"))
    name = get_character_name(data, fname)
    items = data.get("Common Questions", [])
    scores = [extract_choice(q.get(name, "")) for q in items][:9]
    total = sum(s for s in scores if s is not None) if all(s is not None for s in scores) else None
    row = {"No.": idx, "Name": name, **{f"Q{i}": s for i, s in enumerate(scores, 1)}, "Total": total}
    rows.append(row)

with open(OUTPUT_CSV, "w", newline="", encoding="utf-8") as f:
    writer = csv.DictWriter(f, fieldnames=["No.","Name"]+[f"Q{i}" for i in range(1,10)]+["Total"])
    writer.writeheader()
    writer.writerows(rows)

print(f"✅ PHQ-9 summary saved → {OUTPUT_CSV}")
# Out:
# ✅ PHQ-9 summary saved → Analysis/PHQ9/Questionnaire_summary.csv

# %% [markdown]
# ## 😟 GAD-7 Questionnaire Ratings
# Extracts numeric scores from `Conversations/GAD7/Question based Conversation/*.json`.

# %%
# =================== GAD-7 RATING SCRIPT ===================

INPUT_DIR = "Conversations/GAD7/Question based Conversation"
OUTPUT_CSV = "Analysis/GAD7/Questionnaire_summary.csv"
ensure_dir(OUTPUT_CSV)

CHOICE_MAP = {
    "not at all": 0,
    "several days": 1,
    "more than half the days": 2,
    "nearly every day": 3,
}

def extract_choice(answer: str):
    if not answer: return None
    text = answer.lower()
    m = re.search(r"choice\s*:\s*(.+)", text)
    choice = m.group(1).strip() if m else text
    for label, val in CHOICE_MAP.items():
        if label in choice: return val
    return None

rows = []
for idx, fname in enumerate(sorted(os.listdir(INPUT_DIR)), start=1):
    if not fname.endswith(".json"): continue
    data = json.load(open(os.path.join(INPUT_DIR, fname), "r", encoding="utf-8"))
    name = data.get("character") or os.path.splitext(fname)[0]
    items = data.get("Common Questions", [])
    scores = [extract_choice(q.get(name, "")) for q in items][:7]
    total = sum(s for s in scores if s is not None) if all(s is not None for s in scores) else None
    rows.append({"No.": idx, "Name": name, **{f"Q{i}": s for i, s in enumerate(scores, 1)}, "Total": total})

with open(OUTPUT_CSV, "w", newline="", encoding="utf-8") as f:
    writer = csv.DictWriter(f, fieldnames=["No.","Name"]+[f"Q{i}" for i in range(1,8)]+["Total"])
    writer.writeheader()
    writer.writerows(rows)

print(f"✅ GAD-7 summary saved → {OUTPUT_CSV}")
# Out:
# ✅ GAD-7 summary saved → Analysis/GAD7/Questionnaire_summary.csv

# %% [markdown]
# ## ⚡ ASRM Questionnaire Ratings
# Extracts numeric scores from `Conversations/ASRM/Question based Conversation/*.json`.

# %%
# =================== ASRM RATING SCRIPT ===================

INPUT_DIR = "Conversations/ASRM/Question based Conversation"
OUTPUT_CSV = "Analysis/ASRM/Questionnaire_summary.csv"
ensure_dir(OUTPUT_CSV)

CHOICE_MAP = {
    "never": 0,
    "rarely": 1,
    "sometimes": 2,
    "often": 3,
    "very often": 4,
}

def extract_choice(answer: str):
    if not answer: return None
    text = answer.lower()
    m = re.search(r"choice\s*:\s*(.+)", text)
    choice = m.group(1).strip() if m else text
    if "very often" in choice: return 4
    for label, val in CHOICE_MAP.items():
        if label in choice: return val
    return None

rows = []
for idx, fname in enumerate(sorted(os.listdir(INPUT_DIR)), start=1):
    if not fname.endswith(".json"): continue
    data = json.load(open(os.path.join(INPUT_DIR, fname), "r", encoding="utf-8"))
    name = data.get("character") or os.path.splitext(fname)[0]
    items = data.get("Common Questions", [])
    scores = [extract_choice(q.get(name, "")) for q in items][:5]
    total = sum(s for s in scores if s is not None) if all(s is not None for s in scores) else None
    rows.append({"No.": idx, "Name": name, **{f"Q{i}": s for i, s in enumerate(scores, 1)}, "Total": total})

with open(OUTPUT_CSV, "w", newline="", encoding="utf-8") as f:
    writer = csv.DictWriter(f, fieldnames=["No.","Name"]+[f"Q{i}" for i in range(1,6)]+["Total"])
    writer.writeheader()
    writer.writerows(rows)

print(f"✅ ASRM summary saved → {OUTPUT_CSV}")
# Out:
# ✅ ASRM summary saved → Analysis/ASRM/Questionnaire_summary.csv

# %% [markdown]
# ## ✨ Casual Conversation Ratings
# Extracts numeric scores from `Conversations/Casual/*.json`.

# %%
# =================== CASUAL CONVERSATION RATER ===================

INPUT_DIR  = "Conversations/Casual"
OUTPUT_CSV = "Analysis/Casual/Casual_summary.csv"
LOG_DIR    = "Analysis/Casual/_logs"

SCORING_MODEL = "gpt-4.1-mini"  # or "gpt-4.1"
TEMPERATURE   = 0.0

ensure_dir(OUTPUT_CSV)
os.makedirs(LOG_DIR, exist_ok=True)

PROMPT = """
You are an AI rater. Based ONLY on the person's statements in this casual conversation,
estimate likely scores on:
- PHQ-9 (9 items, 0–3)
- GAD-7 (7 items, 0–3)
- ASRM (5 items, 0–4)

Infer from mood, energy, anxiety, sleep, speech, confidence, risk, etc.
If not evident, score the lowest. Output JSON ONLY with this structure:

{
  "PHQ9": {"Q1":0-3,...,"Q9":0-3,"Total":0-27},
  "GAD7": {"Q1":0-3,...,"Q7":0-3,"Total":0-21},
  "ASRM": {"Q1":0-4,...,"Q5":0-4,"Total":0-20}
}
"""

def read_person_lines(path):
    data = json.load(open(path, "r", encoding="utf-8"))
    name = data.get("character", Path(path).stem)
    lines = [t["text"] for t in data.get("turns", []) if t.get("speaker","").lower() != "friend"]
    return name, "\n".join(lines)

def parse_json_response(txt):
    try:
        match = re.search(r"\{.*\}", txt, re.DOTALL)
        if match: return json.loads(match.group(0))
    except Exception:
        return None

def rate_convo(name, convo):
    for attempt in range(3):
        try:
            resp = client.chat.completions.create(
                model=SCORING_MODEL,
                temperature=TEMPERATURE,
                messages=[
                    {"role": "system", "content": "You are a precise psychological scoring assistant."},
                    {"role": "user", "content": PROMPT + "\n\nConversation:\n" + convo}
                ],
            )
            result = parse_json_response(resp.choices[0].message.content)
            if result: return result
        except Exception as e:
            with open(os.path.join(LOG_DIR, f"{name}_error.txt"), "w") as f:
                f.write(str(e))
    return None

def safe_get(d, *path, default=None):
    for p in path:
        if isinstance(d, dict) and p in d:
            d = d[p]
        else:
            return default
    return d

rows = []
for i, fname in enumerate(sorted(os.listdir(INPUT_DIR)), start=1):
    if not fname.endswith(".json"): continue
    name, convo = read_person_lines(os.path.join(INPUT_DIR, fname))
    result = rate_convo(name, convo)
    if not result:
        print(f"⚠️ {name}: no valid JSON")
        continue
    phq, gad, asrm = result.get("PHQ9", {}), result.get("GAD7", {}), result.get("ASRM", {})
    row = {
        "No.": i, "Name": name,
        **{f"PHQ9_Q{j}": safe_get(phq, f"Q{j}") for j in range(1,10)},
        "PHQ9_Total": safe_get(phq, "Total"),
        **{f"GAD7_Q{j}": safe_get(gad, f"Q{j}") for j in range(1,8)},
        "GAD7_Total": safe_get(gad, "Total"),
        **{f"ASRM_Q{j}": safe_get(asrm, f"Q{j}") for j in range(1,6)},
        "ASRM_Total": safe_get(asrm, "Total"),
    }
    rows.append(row)
    print(f"✓ {name}: PHQ9={row['PHQ9_Total']}  GAD7={row['GAD7_Total']}  ASRM={row['ASRM_Total']}")

if rows:
    with open(OUTPUT_CSV, "w", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=list(rows[0].keys()))
        writer.writeheader()
        writer.writerows(rows)
    print(f"\n✅ Casual ratings saved → {OUTPUT_CSV}")
else:
    print("No valid ratings generated.")
# Out:
# ✓ Abigail Hall: PHQ9=12  GAD7=18  ASRM=2
# ✓ Abigail Johnson: PHQ9=8  GAD7=6  ASRM=6
# ✓ Adriana Lopez: PHQ9=8  GAD7=12  ASRM=8
# ✓ Aiden Scott: PHQ9=5  GAD7=6  ASRM=7
# ✓ Aiden Smith: PHQ9=13  GAD7=17  ASRM=7
# ✓ Aiden White: PHQ9=14  GAD7=15  ASRM=11
# ✓ Alice Thompson: PHQ9=5  GAD7=9  ASRM=5
# ✓ Alyssa Taylor: PHQ9=8  GAD7=10  ASRM=3
# ✓ Alyssa Turner: PHQ9=6  GAD7=10  ASRM=7
# ✓ Amelia Lopez: PHQ9=9  GAD7=11  ASRM=8
# ✓ Amy Wilson: PHQ9=21  GAD7=19  ASRM=4
# ✓ Angela Martinez: PHQ9=8  GAD7=10  ASRM=8
# ✓ Anthony Robinson: PHQ9=14  GAD7=17  ASRM=10
# ✓ Anthony White: PHQ9=10  GAD7=12  ASRM=7
# ✓ Anthony Young: PHQ9=14  GAD7=18  ASRM=4
# ✓ Anya Kim: PHQ9=14  GAD7=16  ASRM=4
# ✓ Aria Watson: PHQ9=13  GAD7=17  ASRM=4
# ✓ Ariana Wright: PHQ9=13  GAD7=15  ASRM=4
# ✓ Ava Green: PHQ9=15  GAD7=17  ASRM=4
# ✓ Ava Johnson: PHQ9=14  GAD7=16  ASRM=4
# ✓ Ava Kim: PHQ9=16  GAD7=16  ASRM=4
# ✓ Ava Nguyen: PHQ9=15  GAD7=16  ASRM=4
# ✓ Ava Roberts: PHQ9=13  GAD7=16  ASRM=3
# ✓ Avery Johnson: PHQ9=14  GAD7=19  ASRM=4
# ✓ Avery Knight: PHQ9=8  GAD7=11  ASRM=8
# ✓ Benjamin Harris: PHQ9=8  GAD7=11  ASRM=4
# ✓ Benjamin Taylor: PHQ9=8  GAD7=12  ASRM=7
# ✓ Benjamin Young: PHQ9=21  GAD7=20  ASRM=1
# ✓ Brian Smith: PHQ9=13  GAD7=16  ASRM=13
# ✓ Carlos Rodriguez: PHQ9=15  GAD7=18  ASRM=4
# ✓ Carlos Sanchez: PHQ9=12  GAD7=15  ASRM=4
# ✓ Charlotte Hall: PHQ9=8  GAD7=11  ASRM=8
# ✓ Charlotte Kim: PHQ9=17  GAD7=18  ASRM=4
# ✓ Charlotte Wright: PHQ9=15  GAD7=18  ASRM=4
# ✓ Chloe Johnson: PHQ9=8  GAD7=6  ASRM=7
# ✓ Chloe Mitchell: PHQ9=5  GAD7=8  ASRM=14
# ✓ Chloe Rivera: PHQ9=8  GAD7=11  ASRM=8
# ✓ Chloe Robinson: PHQ9=11  GAD7=14  ASRM=4
# ✓ Chloe Smith: PHQ9=9  GAD7=11  ASRM=8
# ✓ Chloe Taylor: PHQ9=21  GAD7=20  ASRM=0
# ✓ Chloe Williams: PHQ9=20  GAD7=18  ASRM=4
# ✓ Chloe Wong: PHQ9=6  GAD7=8  ASRM=13
# ✓ Clara Nguyen: PHQ9=1  GAD7=5  ASRM=5
# ✓ Colin Harris: PHQ9=15  GAD7=19  ASRM=3
# ✓ Daniel Green: PHQ9=8  GAD7=11  ASRM=6
# ✓ Daniel Kim: PHQ9=11  GAD7=15  ASRM=3
# ✓ Daniel Roberts: PHQ9=2  GAD7=3  ASRM=14
# ✓ Daniel Robinson: PHQ9=8  GAD7=10  ASRM=8
# ✓ Daniel Thompson: PHQ9=7  GAD7=12  ASRM=9
# ✓ David Brown: PHQ9=2  GAD7=7  ASRM=8
# ✓ David Johnson: PHQ9=11  GAD7=15  ASRM=4
# ✓ David Lee: PHQ9=8  GAD7=10  ASRM=7
# ✓ David Tran: PHQ9=6  GAD7=6  ASRM=7
# ✓ Diana Hughes: PHQ9=15  GAD7=18  ASRM=1
# ✓ Dylan Foster: PHQ9=13  GAD7=16  ASRM=5
# ✓ Elena Brown: PHQ9=12  GAD7=16  ASRM=6
# ✓ Eli Mitchell: PHQ9=8  GAD7=11  ASRM=7
# ✓ Ella Harris: PHQ9=13  GAD7=16  ASRM=5
# ✓ Ella Simmons: PHQ9=0  GAD7=7  ASRM=10
# ✓ Ella Turner: PHQ9=8  GAD7=10  ASRM=12
# ✓ Emily Carter: PHQ9=8  GAD7=10  ASRM=5
# ✓ Emily Chen: PHQ9=14  GAD7=18  ASRM=0
# ✓ Emily Rodriguez: PHQ9=8  GAD7=11  ASRM=7
# ✓ Emma Garcia: PHQ9=12  GAD7=15  ASRM=8
# ✓ Emma Johnson: PHQ9=5  GAD7=5  ASRM=7
# ✓ Emma Robinson: PHQ9=13  GAD7=16  ASRM=10
# ✓ Ethan Brooks: PHQ9=14  GAD7=16  ASRM=4
# ✓ Ethan Brown: PHQ9=13  GAD7=17  ASRM=0
# ✓ Ethan Harris: PHQ9=6  GAD7=6  ASRM=14
# ✓ Ethan Parker: PHQ9=8  GAD7=11  ASRM=12
# ✓ Ethan Robinson: PHQ9=5  GAD7=6  ASRM=9
# ✓ Evelyn Hall: PHQ9=7  GAD7=8  ASRM=7
# ✓ Evelyn Ramirez: PHQ9=15  GAD7=18  ASRM=4
# ✓ Evelyn Young: PHQ9=8  GAD7=7  ASRM=7
# ✓ Felix James: PHQ9=20  GAD7=19  ASRM=3
# ✓ Felix Lee: PHQ9=13  GAD7=16  ASRM=4
# ✓ Fiona Walsh: PHQ9=13  GAD7=16  ASRM=4
# ✓ Gabriel Lopez: PHQ9=15  GAD7=17  ASRM=8
# ✓ Gabriel Mitchell: PHQ9=14  GAD7=19  ASRM=4
# ✓ Gabriel Rodriguez: PHQ9=15  GAD7=17  ASRM=5
# ✓ Gary Brown: PHQ9=6  GAD7=6  ASRM=7
# ✓ Grace Carter: PHQ9=9  GAD7=12  ASRM=4
# ✓ Grace Evans: PHQ9=6  GAD7=10  ASRM=8
# ✓ Grace Lee: PHQ9=8  GAD7=10  ASRM=8
# ✓ Grace Turner: PHQ9=12  GAD7=17  ASRM=8
# ✓ Hazel Carter: PHQ9=16  GAD7=19  ASRM=4
# ✓ Henry Adams: PHQ9=8  GAD7=10  ASRM=7
# ✓ Henry Bell: PHQ9=8  GAD7=11  ASRM=7
# ✓ Henry Johnson: PHQ9=14  GAD7=16  ASRM=3
# ✓ Henry Lewis: PHQ9=16  GAD7=18  ASRM=4
# ✓ Henry Moore: PHQ9=4  GAD7=7  ASRM=8
# ✓ Henry Torres: PHQ9=5  GAD7=6  ASRM=7
# ✓ Henry Wilson: PHQ9=22  GAD7=20  ASRM=4
# ✓ Isaac Campbell: PHQ9=0  GAD7=7  ASRM=9
# ✓ Isaac Clarke: PHQ9=5  GAD7=10  ASRM=13
# ✓ Isaac Thompson: PHQ9=8  GAD7=9  ASRM=12
# ✓ Isabella Johnson: PHQ9=13  GAD7=16  ASRM=6
# ✓ Isabella Martinez: PHQ9=8  GAD7=12  ASRM=8
# ✓ Isabella Torres: PHQ9=20  GAD7=20  ASRM=8
# ✓ Isaiah Bennett: PHQ9=0  GAD7=7  ASRM=10
# ✓ Isaiah Chen: PHQ9=8  GAD7=10  ASRM=13
# ✓ Isaiah White: PHQ9=14  GAD7=16  ASRM=7
# ✓ Jack Lewis: PHQ9=0  GAD7=7  ASRM=9
# ✓ Jacob Carter: PHQ9=12  GAD7=17  ASRM=4
# ✓ Jacob White: PHQ9=5  GAD7=8  ASRM=8
# ✓ Jacob Williams: PHQ9=15  GAD7=17  ASRM=4
# ✓ Jacob Wilson: PHQ9=8  GAD7=7  ASRM=13
# ✓ Jade Brooks: PHQ9=11  GAD7=12  ASRM=4
# ✓ James Chen: PHQ9=15  GAD7=17  ASRM=4
# ✓ James Kim: PHQ9=8  GAD7=10  ASRM=8
# ✓ James Lopez: PHQ9=13  GAD7=15  ASRM=6
# ✓ James Thompson: PHQ9=6  GAD7=8  ASRM=7
# ✓ James Wilson: PHQ9=6  GAD7=12  ASRM=5
# ✓ Jasmine Lee: PHQ9=13  GAD7=16  ASRM=7
# ✓ Jasmine Price: PHQ9=14  GAD7=16  ASRM=4
# ✓ Jasmine Taylor: PHQ9=10  GAD7=15  ASRM=4
# ✓ Jason King: PHQ9=13  GAD7=17  ASRM=7
# ✓ Jason Moore: PHQ9=13  GAD7=16  ASRM=8
# ✓ Javier Reyes: PHQ9=16  GAD7=17  ASRM=4
# ✓ Jaxon Taylor: PHQ9=20  GAD7=19  ASRM=0
# ✓ Jessica Lee: PHQ9=0  GAD7=7  ASRM=15
# ✓ Julia Bennett: PHQ9=15  GAD7=17  ASRM=4
# ✓ Julia Collins: PHQ9=15  GAD7=18  ASRM=3
# ✓ Julia Patel: PHQ9=14  GAD7=17  ASRM=5
# ✓ Julia Tran: PHQ9=13  GAD7=15  ASRM=4
# ✓ Julia White: PHQ9=15  GAD7=18  ASRM=4
# ✓ Kaitlyn Nguyen: PHQ9=13  GAD7=17  ASRM=8
# ✓ Katherine Brown: PHQ9=16  GAD7=18  ASRM=4
# ✓ Katherine Scott: PHQ9=8  GAD7=11  ASRM=14
# ✓ Kevin Brown: PHQ9=13  GAD7=16  ASRM=4
# ✓ Kevin James: PHQ9=5  GAD7=5  ASRM=8
# ✓ Kevin Stone: PHQ9=16  GAD7=18  ASRM=0
# ✓ Laura Gomez: PHQ9=8  GAD7=6  ASRM=14
# ✓ Laura Morgan: PHQ9=8  GAD7=7  ASRM=6
# ✓ Laura White: PHQ9=14  GAD7=18  ASRM=4
# ✓ Leah Harris: PHQ9=8  GAD7=10  ASRM=13
# ✓ Leah Scott: PHQ9=13  GAD7=16  ASRM=4
# ✓ Leo Harris: PHQ9=8  GAD7=12  ASRM=12
# ✓ Liam Adams: PHQ9=17  GAD7=20  ASRM=4
# ✓ Liam Garcia: PHQ9=8  GAD7=13  ASRM=4
# ✓ Liam Johnson: PHQ9=12  GAD7=14  ASRM=4
# ✓ Liam Jordan: PHQ9=8  GAD7=10  ASRM=8
# ✓ Liam O'Connell: PHQ9=8  GAD7=9  ASRM=8
# ✓ Lillian Young: PHQ9=11  GAD7=17  ASRM=12
# ✓ Lily Adams: PHQ9=8  GAD7=11  ASRM=7
# ✓ Lily Nguyen: PHQ9=15  GAD7=16  ASRM=4
# ✓ Linda Hernandez: PHQ9=13  GAD7=16  ASRM=4
# ✓ Logan Green: PHQ9=15  GAD7=17  ASRM=3
# ✓ Lucas Martinez: PHQ9=5  GAD7=5  ASRM=12
# ✓ Lucas Mitchell: PHQ9=10  GAD7=13  ASRM=13
# ✓ Lucas Moreau: PHQ9=12  GAD7=16  ASRM=4
# ✓ Luke Sanders: PHQ9=10  GAD7=15  ASRM=8
# ✓ Mackenzie Johnson: PHQ9=8  GAD7=9  ASRM=9
# ✓ Madeline Carter: PHQ9=21  GAD7=20  ASRM=5
# ✓ Madison Clark: PHQ9=5  GAD7=6  ASRM=11
# ✓ Madison Rodriguez: PHQ9=7  GAD7=8  ASRM=10
# ✓ Marcus Brown: PHQ9=17  GAD7=18  ASRM=9
# ✓ Mason Carter: PHQ9=11  GAD7=13  ASRM=8
# ✓ Mason Clark: PHQ9=14  GAD7=18  ASRM=5
# ✓ Matthew Davis: PHQ9=8  GAD7=10  ASRM=8
# ✓ Maxwell Wells: PHQ9=13  GAD7=17  ASRM=4
# ✓ Maya Chen: PHQ9=8  GAD7=11  ASRM=12
# ✓ Maya Collins: PHQ9=14  GAD7=16  ASRM=6
# ✓ Maya Price: PHQ9=14  GAD7=16  ASRM=3
# ✓ Melissa Adams: PHQ9=8  GAD7=10  ASRM=7
# ✓ Mia Patel: PHQ9=11  GAD7=16  ASRM=11
# ✓ Mia Roberts: PHQ9=13  GAD7=14  ASRM=9
# ✓ Mia Torres: PHQ9=14  GAD7=17  ASRM=8
# ✓ Michael Johnson: PHQ9=8  GAD7=7  ASRM=8
# ✓ Michael Robinson: PHQ9=8  GAD7=10  ASRM=13
# ✓ Michael Schwartz: PHQ9=5  GAD7=8  ASRM=12
# ✓ Michael Thompson: PHQ9=8  GAD7=11  ASRM=8
# ✓ Mila Thompson: PHQ9=14  GAD7=15  ASRM=7
# ✓ Natalie Adams: PHQ9=13  GAD7=16  ASRM=4
# ✓ Natalie Perez: PHQ9=15  GAD7=17  ASRM=4
# ✓ Natalie Young: PHQ9=13  GAD7=16  ASRM=3
# ✓ Natasha Kim: PHQ9=5  GAD7=5  ASRM=7
# ✓ Nina Roberts: PHQ9=9  GAD7=10  ASRM=4
# ✓ Nina White: PHQ9=12  GAD7=15  ASRM=4
# ✓ Noah Garcia: PHQ9=13  GAD7=17  ASRM=4
# ✓ Noah Patel: PHQ9=13  GAD7=18  ASRM=4
# ✓ Noah Williams: PHQ9=16  GAD7=18  ASRM=4
# ✓ Nora King: PHQ9=17  GAD7=20  ASRM=4
# ✓ Nora Schmidt: PHQ9=8  GAD7=7  ASRM=8
# ✓ Nora Wood: PHQ9=17  GAD7=19  ASRM=7
# ✓ Oliver Green: PHQ9=13  GAD7=16  ASRM=4
# ✓ Oliver Harris: PHQ9=14  GAD7=18  ASRM=5
# ✓ Oliver Martinez: PHQ9=11  GAD7=12  ASRM=11
# ✓ Oliver Nelson: PHQ9=8  GAD7=6  ASRM=12
# ✓ Oliver Scott: PHQ9=23  GAD7=21  ASRM=4
# ✓ Oliver Thompson: PHQ9=6  GAD7=6  ASRM=8
# ✓ Oliver Young: PHQ9=2  GAD7=7  ASRM=14
# ✓ Olivia Carter: PHQ9=6  GAD7=10  ASRM=7
# ✓ Olivia Cruz: PHQ9=5  GAD7=7  ASRM=8
# ✓ Olivia Smith: PHQ9=0  GAD7=7  ASRM=14
# ✓ Olivia Turner: PHQ9=9  GAD7=11  ASRM=13
# ✓ Olivia White: PHQ9=8  GAD7=11  ASRM=8
# ✓ Owen Ross: PHQ9=13  GAD7=17  ASRM=4
# ✓ Rachel White: PHQ9=13  GAD7=18  ASRM=7
# ✓ Ravi Desai: PHQ9=12  GAD7=16  ASRM=3
# ✓ Rebecca Martin: PHQ9=16  GAD7=18  ASRM=4
# ✓ Riley Campbell: PHQ9=13  GAD7=16  ASRM=4
# ✓ Robert King: PHQ9=5  GAD7=10  ASRM=7
# ✓ Ryan Adams: PHQ9=8  GAD7=11  ASRM=4
# ✓ Ryan O'Donnell: PHQ9=3  GAD7=7  ASRM=7
# ✓ Ryan Patel: PHQ9=8  GAD7=10  ASRM=8
# ✓ Sam Patel: PHQ9=17  GAD7=20  ASRM=4
# ✓ Samantha Brooks: PHQ9=14  GAD7=16  ASRM=4
# ✓ Samantha Green: PHQ9=9  GAD7=12  ASRM=5
# ✓ Samantha Kim: PHQ9=14  GAD7=19  ASRM=4
# ✓ Samantha Ryan: PHQ9=8  GAD7=11  ASRM=13
# ✓ Samuel Johnson: PHQ9=8  GAD7=6  ASRM=7
# ✓ Samuel Lee: PHQ9=12  GAD7=16  ASRM=8
# ✓ Samuel Turner: PHQ9=3  GAD7=6  ASRM=10
# ✓ Santiago Gomez: PHQ9=15  GAD7=17  ASRM=7
# ✓ Sara Patel: PHQ9=13  GAD7=17  ASRM=11
# ✓ Sarah Patel: PHQ9=5  GAD7=7  ASRM=5
# ✓ Sarah Turner: PHQ9=16  GAD7=18  ASRM=4
# ✓ Scarlett Harris: PHQ9=8  GAD7=7  ASRM=13
# ✓ Sebastian King: PHQ9=15  GAD7=18  ASRM=4
# ✓ Sofia Martinez: PHQ9=12  GAD7=14  ASRM=8
# ✓ Sofia Rivera: PHQ9=6  GAD7=10  ASRM=5
# ✓ Sophia Chen: PHQ9=8  GAD7=11  ASRM=9
# ✓ Sophia Davis: PHQ9=17  GAD7=20  ASRM=4
# ✓ Sophia Hernandez: PHQ9=14  GAD7=17  ASRM=4
# ✓ Sophia Kim: PHQ9=13  GAD7=16  ASRM=7
# ✓ Sophia Nguyen: PHQ9=13  GAD7=17  ASRM=11
# ✓ Sophie Allen: PHQ9=13  GAD7=12  ASRM=3
# ✓ Sophie Martin: PHQ9=13  GAD7=17  ASRM=4
# ✓ Susan Patel: PHQ9=8  GAD7=11  ASRM=8
# ✓ Sydney Martinez: PHQ9=8  GAD7=12  ASRM=7
# ✓ Tarek Ameen: PHQ9=15  GAD7=18  ASRM=9
# ✓ Thomas Garcia: PHQ9=8  GAD7=8  ASRM=6
# ✓ Thomas Wright: PHQ9=14  GAD7=17  ASRM=3
# ✓ Tina Rodriguez: PHQ9=12  GAD7=16  ASRM=8
# ✓ Tobias Johnson: PHQ9=15  GAD7=18  ASRM=4
# ✓ Tommy Wright: PHQ9=11  GAD7=16  ASRM=4
# ✓ Trevor Scott: PHQ9=12  GAD7=15  ASRM=8
# ✓ Tristan White: PHQ9=5  GAD7=10  ASRM=4
# ✓ Victor Gomez: PHQ9=13  GAD7=14  ASRM=8
# ✓ Victor Hall: PHQ9=8  GAD7=11  ASRM=5
# ✓ Victoria Brown: PHQ9=2  GAD7=7  ASRM=7
# ✓ Victoria Foster: PHQ9=12  GAD7=12  ASRM=11
# ✓ Victoria King: PHQ9=20  GAD7=20  ASRM=5
# ✓ Wyatt Hall: PHQ9=14  GAD7=16  ASRM=8
# ✓ Xavier Evans: PHQ9=13  GAD7=16  ASRM=3
# ✓ Zachary Lee: PHQ9=14  GAD7=20  ASRM=0
# ✓ Zoe Anderson: PHQ9=14  GAD7=17  ASRM=10
# ✓ Zoe King: PHQ9=14  GAD7=16  ASRM=7
# ✓ Zoe Wilson: PHQ9=8  GAD7=9  ASRM=9
#
# ✅ Casual ratings saved → Analysis/Casual/Casual_summary.csv

# %% [markdown]
# ## Filtering Results

# %% [markdown]
# #### PQH Filtering

# %%
# save as: filter_phq9_severe.py
import pandas as pd
import os

# ---- Inputs / Outputs ----
INPUT_CSV  = "Analysis/combined_sorted.csv"   # change if needed
OUTPUT_CSV = "Analysis/Filtered/PHQ9_Severe.csv"       # per your request ("PHQ9_Severe")

# ---- Load ----
df = pd.read_csv(INPUT_CSV)

# Be flexible about column names
def find_col(candidates):
    lower_map = {c.lower(): c for c in df.columns}
    for cand in candidates:
        if cand.lower() in lower_map:
            return lower_map[cand.lower()]
    return None

name_col   = find_col(["Name", "name", "character", "Character"])
score_col  = find_col(["PHQ9_Score", "phq9_score", "PHQ9", "phq9"])
estim_col  = find_col(["PHQ9_Estimate", "phq9_estimate", "PHQ9_est", "phq9_est"])

if not all([name_col, score_col, estim_col]):
    raise KeyError(
        "Could not find required columns. "
        f"Have: {list(df.columns)}"
    )

# ---- Filter: PHQ9_Score >= 15 ----
df[score_col] = pd.to_numeric(df[score_col], errors="coerce")
df_severe = df[df[score_col] >= 15].copy()

# ---- Select and save ----
out = df_severe[[name_col, score_col, estim_col]].rename(
    columns={name_col: "Name", score_col: "PHQ9_Score", estim_col: "PHQ9_Estimate"}
)

os.makedirs(os.path.dirname(OUTPUT_CSV) or ".", exist_ok=True)
out.to_csv(OUTPUT_CSV, index=False, encoding="utf-8")

print(f"Saved {len(out)} rows → {OUTPUT_CSV}")
# Out:
# Saved 103 rows → Analysis/Filtered/PHQ9_Severe.csv

# %% [markdown]
# #### GAD7 Filtering

# %%
# save as: filter_gad7_severe.py
import pandas as pd
import os

# ---- Inputs / Outputs ----
INPUT_CSV  = "Analysis/combined_sorted.csv"   # change if needed
OUTPUT_CSV = "Analysis/Filtered/GAD7_Severe.csv"       # per your request ("GAD7_Severe")

# ---- Load ----
df = pd.read_csv(INPUT_CSV)

# Be flexible about column names
def find_col(candidates):
    lower_map = {c.lower(): c for c in df.columns}
    for cand in candidates:
        if cand.lower() in lower_map:
            return lower_map[cand.lower()]
    return None

name_col   = find_col(["Name", "name", "character", "Character"])
score_col  = find_col(["GAD7_Score", "gad7_score", "GAD7", "gad7"])
estim_col  = find_col(["GAD7_Estimate", "gad7_estimate", "GAD7_est", "gad7_est"])

if not all([name_col, score_col, estim_col]):
    raise KeyError(
        "Could not find required columns. "
        f"Have: {list(df.columns)}"
    )

# ---- Filter: GAD7_Score >= 10 ----
df[score_col] = pd.to_numeric(df[score_col], errors="coerce")
df_severe = df[df[score_col] >= 10].copy()

# ---- Select and save ----
out = df_severe[[name_col, score_col, estim_col]].rename(
    columns={name_col: "Name", score_col: "GAD7_Score", estim_col: "GAD7_Estimate"}
)

os.makedirs(os.path.dirname(OUTPUT_CSV) or ".", exist_ok=True)
out.to_csv(OUTPUT_CSV, index=False, encoding="utf-8")

print(f"Saved {len(out)} rows → {OUTPUT_CSV}")
# Out:
# Saved 418 rows → Analysis/Filtered/GAD7_Severe.csv

# %% [markdown]
# #### ASRM Filtering

# %%
# save as: filter_asrm_severe.py
import pandas as pd
import os

# ---- Inputs / Outputs ----
INPUT_CSV  = "Analysis/combined_sorted.csv"   # change if needed
OUTPUT_CSV = "Analysis/Filtered/ASRM_Severe.csv"       # per your request ("ASRM_Severe")

# ---- Load ----
df = pd.read_csv(INPUT_CSV)

# Be flexible about column names
def find_col(candidates):
    lower_map = {c.lower(): c for c in df.columns}
    for cand in candidates:
        if cand.lower() in lower_map:
            return lower_map[cand.lower()]
    return None

name_col   = find_col(["Name", "name", "character", "Character"])
score_col  = find_col(["ASRM_Score", "asrm_score", "ASRM", "asrm"])
estim_col  = find_col(["ASRM_Estimate", "asrm_estimate", "ASRM_est", "asrm_est"])

if not all([name_col, score_col, estim_col]):
    raise KeyError(
        "Could not find required columns. "
        f"Have: {list(df.columns)}"
    )

# ---- Filter: GAD7_Score >= 6 ----
df[score_col] = pd.to_numeric(df[score_col], errors="coerce")
df_severe = df[df[score_col] >= 6].copy()

# ---- Select and save ----
out = df_severe[[name_col, score_col, estim_col]].rename(
    columns={name_col: "Name", score_col: "ASRM_Score", estim_col: "ASRM_Estimate"}
)

os.makedirs(os.path.dirname(OUTPUT_CSV) or ".", exist_ok=True)
out.to_csv(OUTPUT_CSV, index=False, encoding="utf-8")

print(f"Saved {len(out)} rows → {OUTPUT_CSV}")
# Out:
# Saved 731 rows → Analysis/Filtered/ASRM_Severe.csv
